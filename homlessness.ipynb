# %%
import pandas as pd
import numpy as np

# %%
hic_2021 = pd.read_csv('2021-HIC-Counts-by-State.csv')

# %%
hic_2021
# Out:
#         Row # CocState                                 CoC  Coc\ID  HudNum  \
# 0      511617       OH  Akron, Barberton/Summit County CoC    1350  OH-506
# 1      511618       OH  Akron, Barberton/Summit County CoC    1350  OH-506
# 2      511625       OH  Akron, Barberton/Summit County CoC    1350  OH-506
# 3      523278       OH  Akron, Barberton/Summit County CoC    1350  OH-506
# 4      511673       OH  Akron, Barberton/Summit County CoC    1350  OH-506
# ...       ...      ...                                 ...     ...     ...
# 27631  482609       WY               Wyoming Statewide CoC    1269  WY-500
# 27632  482616       WY               Wyoming Statewide CoC    1269  WY-500
# 27633  470616       WY               Wyoming Statewide CoC    1269  WY-500
# 27634  470661       WY               Wyoming Statewide CoC    1269  WY-500
# 27635  470617       WY               Wyoming Statewide CoC    1269  WY-500
#
# ...

# %%
df = hic_2021

# %%
# Check States
df.CocState.unique()
# Out:
# array(['OH', 'AL', 'AK', 'NM', 'VA', 'CA', 'TX', 'TN', 'AZ', 'AR', 'NC',
#        'GA', 'NJ', 'MA', 'IL', 'MD', 'MI', 'PA', 'NY', 'ID', 'CT', 'VT',
#        'OR', 'WV', 'SC', 'FL', 'CO', 'MN', 'DE', 'IA', 'DC', 'WA', 'GU',
#        'MS', 'HI', 'IN', 'MO', 'KS', 'KY', 'LA', 'NV', 'NE', 'WI', 'ME',
#        'NH', 'MT', 'OK', 'ND', 'MP', 'UT', 'PR', 'RI', 'SD', 'VI', 'WY'],
#       dtype=object)

# %% [markdown]
# All 50 States plus 5 Territories

# %%
# Check NaN
df.isnull().sum()
# Out:
# Row #                                         0
# CocState                                      0
# CoC                                           0
# Coc\ID                                        0
# HudNum                                        0
#                                           ...
# questionDesiresToUseDescriptorElements    22007
# notes                                     22573
# projectNotes                              24981
# sandyRelated                                  0
# sandyRelatedNote                          27585
# Length: 96, dtype: int64

# %%
# Column Names
df.columns
# Out:
# Index(['Row #', 'CocState', 'CoC', 'Coc\ID', 'HudNum', 'Status', 'year',
#        'Organization ID', 'Organization Name', 'HMIS Org ID', 'Project ID',
#        'Project Name', 'HMIS Project ID', 'HIC Date', 'Project Type',
#        'Bed Type', 'Geo Code', 'HMIS Participating', 'Inventory Type',
#        'beginsOperationsWithinYear', 'Target Population', 'mcKinneyVentoEsg',
#        'mcKinneyVentoEsgEs', 'mcKinneyVentoEsgRrh', 'mcKinneyVentoEsgCov',
#        'mcKinneyVentoEsgEsCov', 'mcKinneyVentoEsgRrhCov', 'mcKinneyVentoCoc',
#        'mcKinneyVentoCocSh', 'mcKinneyVentoCocTh', 'mcKinneyVentoCocPsh',
#        'mcKinneyVentoCocRrh', 'mcKinneyVentoCocSro', 'mcKinneyVentoCocYhdp',
#        'mcKinneyVentoCocThRrh', 'mcKinneyVentoSpC', 'mcKinneyVentoS8',
#        'mcKinneyVentoShp', 'federalFundingVash', 'federalFundingSsvf',
#        'federalFundingGpd', 'federalFundingGpdBh', 'federalFundingGpdLd',
#        'federalFundingGpdHh', 'federalFundingGpdCt', 'federalFundingGpdSith',
# ...
